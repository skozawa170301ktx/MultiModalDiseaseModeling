# %% [markdown]
# # 10_2_build_LGBM_TI.ipynb
# Let LGBM learn the relationship between Path similarity (Levenshtein ratio) pattern and TI pattern.
#
# - Using LGBM.
# - Perform downsamling + vaging.
# - After downsampling, the upper limit of the number of rows in the matrix is set to 1000.
# - Separate the data after downsampling into training data and validation data.
# - Learning is performed while tuning the parameters by optuna.integration.lightgbm.
# - Bagging is done 10 times.
#
# ### input
# - 5_X_train_test_datafile/train/X_train_PCA_TI.npz : Training data for explanatory variables in TI
# - 5_X_train_test_datafile/train/Y_train_TI.npz : Training data for response variables in TI
# - 10_build_LGBM_code/output/Train_Test_count_TI.csv : A file containing the ID of the TI that will create the model
#
# ### output
# - 11_LGBM/model_ti_*.pkl : LightGBM trained on training data

# %%
import pandas as pd
from imblearn.under_sampling import RandomUnderSampler
from scipy.sparse import load_npz
from sklearn.model_selection import train_test_split
import optuna.integration.lightgbm as lgb
import pickle
import warnings
warnings.filterwarnings('ignore')

# %%
Y_train = load_npz('../5_X_train_test_datafile/Y/Y_train_SE.npz')

# %%
Y_train.shape
# Out:
# (60732, 177)

# %%
def bagging(seed):
    sampler = RandomUnderSampler(random_state=seed, replacement=True, sampling_strategy = 0.5)
    X_resampled, y_resampled = sampler.fit_resample(X_train.toarray(), y_train.toarray())
    if X_resampled.shape[0] > 1000:
        X_resampled, _, y_resampled, _ = train_test_split(X_resampled, y_resampled, train_size=1000, random_state=0, shuffle=True)
    
    X_train2, X_valid, y_train2, y_valid = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=0, shuffle=True)

    lgb_train = lgb.Dataset(X_train2, y_train2)
    lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train)
    
    model = lgb.train(params,
                lgb_train,
                num_boost_round=200,
                valid_sets=[lgb_train, lgb_eval],
                early_stopping_rounds=50, verbose_eval=False,
                optuna_seed=0,
                verbosity = -1
               )
    
    with open('../11_LGBM_SE/model_se_'+str(i)+'_'+str(seed)+'.pkl', 'wb') as f:
        pickle.dump(model, f)
    
    return model

# %%
list_0 = []

for i in range(177):
    X_train = load_npz('../5_X_train_test_datafile/train/X_train_Clustering_SE_'+ str(i) +'.npz')
    y_train = Y_train[:, i]
    
    params = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'verbosity' : -1,
    'deterministic':True,
    'force_row_wise':True
    }
      
    models = []

    try:
        for k in range(10):
            models.append(bagging(k))
    

    except:
        list_0.append(i)
# Out:
# [I 2022-02-01 00:34:35,419] A new study created in memory with name: no-name-3f5bc94a-01ab-47bd-9998-d1ee6fd32836
# feature_fraction, val_score: 0.293163: 100%|#############################################| 7/7 [00:01<00:00,  4.41it/s]
# num_leaves, val_score: 0.293163: 100%|#################################################| 20/20 [00:04<00:00,  4.37it/s]
# bagging, val_score: 0.288738: 100%|####################################################| 10/10 [00:02<00:00,  4.85it/s]
# feature_fraction_stage2, val_score: 0.288738: 100%|######################################| 6/6 [00:01<00:00,  4.28it/s]
# regularization_factors, val_score: 0.285510: 100%|#####################################| 20/20 [00:04<00:00,  4.28it/s]
# min_data_in_leaf, val_score: 0.285510: 100%|#############################################| 5/5 [00:01<00:00,  4.69it/s]
# feature_fraction, val_score: 0.226284: 100%|#############################################| 7/7 [00:01<00:00,  3.99it/s]
# num_leaves, val_score: 0.226259: 100%|#################################################| 20/20 [00:04<00:00,  4.37it/s]
# bagging, val_score: 0.225566: 100%|####################################################| 10/10 [00:02<00:00,  3.80it/s]
# feature_fraction_stage2, val_score: 0.225566: 100%|######################################| 3/3 [00:00<00:00,  4.11it/s]
# regularization_factors, val_score: 0.225566: 100%|#####################################| 20/20 [00:05<00:00,  3.91it/s]
# min_data_in_leaf, val_score: 0.216245: 100%|#############################################| 5/5 [00:01<00:00,  4.10it/s]
# feature_fraction, val_score: 0.271356: 100%|#############################################| 7/7 [00:01<00:00,  4.34it/s]
# num_leaves, val_score: 0.250797: 100%|#################################################| 20/20 [00:04<00:00,  4.29it/s]
# bagging, val_score: 0.250797: 100%|####################################################| 10/10 [00:02<00:00,  4.80it/s]
# feature_fraction_stage2, val_score: 0.250797: 100%|######################################| 6/6 [00:01<00:00,  4.82it/s]
# regularization_factors, val_score: 0.250797: 100%|#####################################| 20/20 [00:04<00:00,  4.56it/s]
# min_data_in_leaf, val_score: 0.242453: 100%|#############################################| 5/5 [00:01<00:00,  4.89it/s]
# feature_fraction, val_score: 0.266697: 100%|#############################################| 7/7 [00:01<00:00,  4.93it/s]
# num_leaves, val_score: 0.266235: 100%|#################################################| 20/20 [00:03<00:00,  5.16it/s]
# bagging, val_score: 0.266235: 100%|####################################################| 10/10 [00:01<00:00,  5.12it/s]
# feature_fraction_stage2, val_score: 0.261784: 100%|######################################| 6/6 [00:00<00:00,  6.08it/s]
# regularization_factors, val_score: 0.256255: 100%|#####################################| 20/20 [00:03<00:00,  5.35it/s]
# min_data_in_leaf, val_score: 0.244250: 100%|#############################################| 5/5 [00:00<00:00,  5.17it/s]
# feature_fraction, val_score: 0.179898: 100%|#############################################| 7/7 [00:02<00:00,  3.06it/s]
# num_leaves, val_score: 0.168287: 100%|#################################################| 20/20 [00:05<00:00,  3.45it/s]
# bagging, val_score: 0.168287: 100%|####################################################| 10/10 [00:02<00:00,  3.38it/s]
# feature_fraction_stage2, val_score: 0.168287: 100%|######################################| 6/6 [00:01<00:00,  3.85it/s]
# regularization_factors, val_score: 0.168286: 100%|#####################################| 20/20 [00:05<00:00,  3.47it/s]
# min_data_in_leaf, val_score: 0.168286: 100%|#############################################| 5/5 [00:01<00:00,  4.42it/s]
# feature_fraction, val_score: 0.271606: 100%|#############################################| 7/7 [00:01<00:00,  4.29it/s]
# num_leaves, val_score: 0.271606: 100%|#################################################| 20/20 [00:05<00:00,  3.69it/s]
# bagging, val_score: 0.271606: 100%|####################################################| 10/10 [00:02<00:00,  4.18it/s]
# feature_fraction_stage2, val_score: 0.271606: 100%|######################################| 6/6 [00:01<00:00,  3.84it/s]
# regularization_factors, val_score: 0.271606: 100%|#####################################| 20/20 [00:05<00:00,  3.69it/s]
# min_data_in_leaf, val_score: 0.252401: 100%|#############################################| 5/5 [00:01<00:00,  3.58it/s]
# feature_fraction, val_score: 0.313712: 100%|#############################################| 7/7 [00:01<00:00,  4.60it/s]
# num_leaves, val_score: 0.313712: 100%|#################################################| 20/20 [00:04<00:00,  4.35it/s]
# bagging, val_score: 0.313712: 100%|####################################################| 10/10 [00:01<00:00,  5.04it/s]
# feature_fraction_stage2, val_score: 0.313712: 100%|######################################| 3/3 [00:00<00:00,  4.24it/s]
# regularization_factors, val_score: 0.313711: 100%|#####################################| 20/20 [00:04<00:00,  4.37it/s]
# min_data_in_leaf, val_score: 0.263171: 100%|#############################################| 5/5 [00:01<00:00,  4.18it/s]
# feature_fraction, val_score: 0.250934: 100%|#############################################| 7/7 [00:01<00:00,  4.75it/s]
# num_leaves, val_score: 0.250934: 100%|#################################################| 20/20 [00:03<00:00,  5.20it/s]
# bagging, val_score: 0.244375: 100%|####################################################| 10/10 [00:01<00:00,  5.04it/s]
# feature_fraction_stage2, val_score: 0.244375: 100%|######################################| 6/6 [00:01<00:00,  4.58it/s]
# regularization_factors, val_score: 0.244375: 100%|#####################################| 20/20 [00:04<00:00,  4.29it/s]
# min_data_in_leaf, val_score: 0.207662: 100%|#############################################| 5/5 [00:01<00:00,  4.73it/s]
# feature_fraction, val_score: 0.195446: 100%|#############################################| 7/7 [00:02<00:00,  3.22it/s]
# num_leaves, val_score: 0.195446: 100%|#################################################| 20/20 [00:05<00:00,  3.44it/s]
# bagging, val_score: 0.191912: 100%|####################################################| 10/10 [00:02<00:00,  3.45it/s]
# feature_fraction_stage2, val_score: 0.189645: 100%|######################################| 6/6 [00:01<00:00,  3.18it/s]
# regularization_factors, val_score: 0.189486: 100%|#####################################| 20/20 [00:06<00:00,  3.11it/s]
# min_data_in_leaf, val_score: 0.174576: 100%|#############################################| 5/5 [00:01<00:00,  3.46it/s]
# feature_fraction, val_score: 0.066274: 100%|#############################################| 7/7 [00:00<00:00, 18.37it/s]
# num_leaves, val_score: 0.066274: 100%|#################################################| 20/20 [00:01<00:00, 18.29it/s]
# bagging, val_score: 0.066243: 100%|####################################################| 10/10 [00:00<00:00, 19.21it/s]
# feature_fraction_stage2, val_score: 0.066243: 100%|######################################| 6/6 [00:00<00:00, 18.30it/s]
# regularization_factors, val_score: 0.050034: 100%|#####################################| 20/20 [00:01<00:00, 16.90it/s]
# min_data_in_leaf, val_score: 0.050034: 100%|#############################################| 5/5 [00:00<00:00, 14.22it/s]
# feature_fraction, val_score: 0.003980: 100%|#############################################| 7/7 [00:00<00:00, 12.68it/s]
# num_leaves, val_score: 0.003980: 100%|#################################################| 20/20 [00:01<00:00, 13.28it/s]
# bagging, val_score: 0.002250: 100%|####################################################| 10/10 [00:00<00:00, 14.65it/s]
# feature_fraction_stage2, val_score: 0.002104: 100%|######################################| 6/6 [00:00<00:00, 17.36it/s]
# regularization_factors, val_score: 0.002104: 100%|#####################################| 20/20 [00:01<00:00, 15.88it/s]
# min_data_in_leaf, val_score: 0.001874: 100%|#############################################| 5/5 [00:00<00:00, 15.23it/s]
# feature_fraction, val_score: 0.004330: 100%|#############################################| 7/7 [00:00<00:00, 11.93it/s]
# num_leaves, val_score: 0.004330: 100%|#################################################| 20/20 [00:01<00:00, 10.76it/s]
# bagging, val_score: 0.001279: 100%|####################################################| 10/10 [00:00<00:00, 12.18it/s]
# feature_fraction_stage2, val_score: 0.001243: 100%|######################################| 6/6 [00:00<00:00, 11.57it/s]
# regularization_factors, val_score: 0.001194: 100%|#####################################| 20/20 [00:01<00:00, 10.68it/s]
# min_data_in_leaf, val_score: 0.001057: 100%|#############################################| 5/5 [00:00<00:00, 11.73it/s]
# feature_fraction, val_score: 0.004938: 100%|#############################################| 7/7 [00:00<00:00, 14.03it/s]
# num_leaves, val_score: 0.004938: 100%|#################################################| 20/20 [00:01<00:00, 13.66it/s]
# bagging, val_score: 0.002971: 100%|####################################################| 10/10 [00:00<00:00, 16.97it/s]
# feature_fraction_stage2, val_score: 0.002854: 100%|######################################| 6/6 [00:00<00:00, 17.19it/s]
# regularization_factors, val_score: 0.002854: 100%|#####################################| 20/20 [00:01<00:00, 14.98it/s]
# min_data_in_leaf, val_score: 0.002583: 100%|#############################################| 5/5 [00:00<00:00, 16.15it/s]
# feature_fraction, val_score: 0.005345: 100%|#############################################| 7/7 [00:00<00:00, 15.75it/s]
# num_leaves, val_score: 0.005345: 100%|#################################################| 20/20 [00:01<00:00, 14.84it/s]
# bagging, val_score: 0.004438: 100%|####################################################| 10/10 [00:00<00:00, 16.50it/s]
# feature_fraction_stage2, val_score: 0.004364: 100%|######################################| 6/6 [00:00<00:00, 17.29it/s]
# regularization_factors, val_score: 0.004364: 100%|#####################################| 20/20 [00:01<00:00, 14.88it/s]
# min_data_in_leaf, val_score: 0.003258: 100%|#############################################| 5/5 [00:00<00:00, 13.59it/s]
# feature_fraction, val_score: 0.022516: 100%|#############################################| 7/7 [00:00<00:00, 17.02it/s]
# num_leaves, val_score: 0.022516: 100%|#################################################| 20/20 [00:01<00:00, 14.21it/s]
# bagging, val_score: 0.019357: 100%|####################################################| 10/10 [00:00<00:00, 15.27it/s]
# feature_fraction_stage2, val_score: 0.019357: 100%|######################################| 3/3 [00:00<00:00, 14.74it/s]
# regularization_factors, val_score: 0.018785: 100%|#####################################| 20/20 [00:01<00:00, 13.52it/s]
# min_data_in_leaf, val_score: 0.018785: 100%|#############################################| 5/5 [00:00<00:00, 15.33it/s]
# feature_fraction, val_score: 0.003830: 100%|#############################################| 7/7 [00:00<00:00, 12.28it/s]
# num_leaves, val_score: 0.003830: 100%|#################################################| 20/20 [00:01<00:00, 11.70it/s]
# bagging, val_score: 0.000958: 100%|####################################################| 10/10 [00:00<00:00, 15.11it/s]
# feature_fraction_stage2, val_score: 0.000958: 100%|######################################| 6/6 [00:00<00:00, 13.40it/s]
# regularization_factors, val_score: 0.000958: 100%|#####################################| 20/20 [00:01<00:00, 12.95it/s]
# min_data_in_leaf, val_score: 0.000958: 100%|#############################################| 5/5 [00:00<00:00, 14.24it/s]
# feature_fraction, val_score: 0.003998: 100%|#############################################| 7/7 [00:00<00:00, 11.83it/s]
# num_leaves, val_score: 0.003998: 100%|#################################################| 20/20 [00:02<00:00,  9.57it/s]
# bagging, val_score: 0.002262: 100%|####################################################| 10/10 [00:00<00:00, 13.55it/s]
# feature_fraction_stage2, val_score: 0.002262: 100%|######################################| 6/6 [00:00<00:00, 14.30it/s]
# regularization_factors, val_score: 0.002262: 100%|#####################################| 20/20 [00:01<00:00, 13.05it/s]
# min_data_in_leaf, val_score: 0.001946: 100%|#############################################| 5/5 [00:00<00:00, 13.95it/s]
# feature_fraction, val_score: 0.003611: 100%|#############################################| 7/7 [00:00<00:00, 12.31it/s]
# num_leaves, val_score: 0.003611: 100%|#################################################| 20/20 [00:01<00:00, 11.95it/s]
# bagging, val_score: 0.002091: 100%|####################################################| 10/10 [00:00<00:00, 14.17it/s]
# feature_fraction_stage2, val_score: 0.002081: 100%|######################################| 6/6 [00:00<00:00, 14.55it/s]
# regularization_factors, val_score: 0.002038: 100%|#####################################| 20/20 [00:01<00:00, 14.61it/s]
# min_data_in_leaf, val_score: 0.001950: 100%|#############################################| 5/5 [00:00<00:00, 15.34it/s]
# feature_fraction, val_score: 0.008090: 100%|#############################################| 7/7 [00:00<00:00, 11.64it/s]
# num_leaves, val_score: 0.008090: 100%|#################################################| 20/20 [00:01<00:00, 11.17it/s]
# bagging, val_score: 0.005280: 100%|####################################################| 10/10 [00:00<00:00, 13.20it/s]
# feature_fraction_stage2, val_score: 0.005280: 100%|######################################| 6/6 [00:00<00:00, 11.34it/s]
# regularization_factors, val_score: 0.005280: 100%|#####################################| 20/20 [00:01<00:00, 11.38it/s]
# min_data_in_leaf, val_score: 0.005280: 100%|#############################################| 5/5 [00:00<00:00, 13.07it/s]
# feature_fraction, val_score: 0.007882: 100%|#############################################| 7/7 [00:00<00:00, 14.86it/s]
# num_leaves, val_score: 0.007882: 100%|#################################################| 20/20 [00:01<00:00, 11.31it/s]
# bagging, val_score: 0.003364: 100%|####################################################| 10/10 [00:00<00:00, 12.88it/s]
# feature_fraction_stage2, val_score: 0.003364: 100%|######################################| 6/6 [00:00<00:00, 13.23it/s]
# regularization_factors, val_score: 0.003356: 100%|#####################################| 20/20 [00:01<00:00, 12.47it/s]
# min_data_in_leaf, val_score: 0.003153: 100%|#############################################| 5/5 [00:00<00:00, 15.13it/s]
# feature_fraction, val_score: 0.007272: 100%|#############################################| 7/7 [00:00<00:00, 12.92it/s]
# num_leaves, val_score: 0.007272: 100%|#################################################| 20/20 [00:01<00:00, 10.05it/s]
# bagging, val_score: 0.003366: 100%|####################################################| 10/10 [00:00<00:00, 12.90it/s]
# feature_fraction_stage2, val_score: 0.003300: 100%|######################################| 6/6 [00:00<00:00, 13.24it/s]
# regularization_factors, val_score: 0.003300: 100%|#####################################| 20/20 [00:01<00:00, 12.10it/s]
# min_data_in_leaf, val_score: 0.002886: 100%|#############################################| 5/5 [00:00<00:00, 15.08it/s]
# feature_fraction, val_score: 0.008025: 100%|#############################################| 7/7 [00:00<00:00, 13.02it/s]
# num_leaves, val_score: 0.008025: 100%|#################################################| 20/20 [00:01<00:00, 12.55it/s]
# bagging, val_score: 0.005725: 100%|####################################################| 10/10 [00:00<00:00, 17.00it/s]
# feature_fraction_stage2, val_score: 0.005547: 100%|######################################| 3/3 [00:00<00:00, 16.67it/s]
# regularization_factors, val_score: 0.005520: 100%|#####################################| 20/20 [00:01<00:00, 15.99it/s]
# min_data_in_leaf, val_score: 0.005345: 100%|#############################################| 5/5 [00:00<00:00, 16.81it/s]
# feature_fraction, val_score: 0.011026: 100%|#############################################| 7/7 [00:00<00:00, 17.12it/s]
# num_leaves, val_score: 0.011026: 100%|#################################################| 20/20 [00:01<00:00, 14.28it/s]
# bagging, val_score: 0.011026: 100%|####################################################| 10/10 [00:00<00:00, 15.37it/s]
# feature_fraction_stage2, val_score: 0.010948: 100%|######################################| 6/6 [00:00<00:00, 15.27it/s]
# regularization_factors, val_score: 0.010948: 100%|#####################################| 20/20 [00:01<00:00, 13.98it/s]
# min_data_in_leaf, val_score: 0.008940: 100%|#############################################| 5/5 [00:00<00:00, 16.15it/s]
# feature_fraction, val_score: 0.008668: 100%|#############################################| 7/7 [00:00<00:00, 16.57it/s]
# num_leaves, val_score: 0.008668: 100%|#################################################| 20/20 [00:01<00:00, 14.12it/s]
# bagging, val_score: 0.005639: 100%|####################################################| 10/10 [00:00<00:00, 14.53it/s]
# feature_fraction_stage2, val_score: 0.005582: 100%|######################################| 3/3 [00:00<00:00, 14.56it/s]
# regularization_factors, val_score: 0.005538: 100%|#####################################| 20/20 [00:01<00:00, 13.97it/s]
# min_data_in_leaf, val_score: 0.005388: 100%|#############################################| 5/5 [00:00<00:00, 16.10it/s]
# feature_fraction, val_score: 0.023842: 100%|#############################################| 7/7 [00:00<00:00, 19.04it/s]
# num_leaves, val_score: 0.023842: 100%|#################################################| 20/20 [00:01<00:00, 15.95it/s]
# bagging, val_score: 0.023842: 100%|####################################################| 10/10 [00:00<00:00, 16.40it/s]
# feature_fraction_stage2, val_score: 0.021958: 100%|######################################| 3/3 [00:00<00:00, 16.64it/s]
# regularization_factors, val_score: 0.021906: 100%|#####################################| 20/20 [00:01<00:00, 15.08it/s]
# min_data_in_leaf, val_score: 0.018373: 100%|#############################################| 5/5 [00:00<00:00, 16.60it/s]
# feature_fraction, val_score: 0.008297: 100%|#############################################| 7/7 [00:00<00:00, 11.62it/s]
# num_leaves, val_score: 0.008297: 100%|#################################################| 20/20 [00:01<00:00, 10.81it/s]
# bagging, val_score: 0.003957: 100%|####################################################| 10/10 [00:00<00:00, 15.13it/s]
# feature_fraction_stage2, val_score: 0.003862: 100%|######################################| 6/6 [00:00<00:00, 15.77it/s]
# regularization_factors, val_score: 0.003862: 100%|#####################################| 20/20 [00:01<00:00, 13.51it/s]
# min_data_in_leaf, val_score: 0.003603: 100%|#############################################| 5/5 [00:00<00:00, 14.47it/s]
# feature_fraction, val_score: 0.007812: 100%|#############################################| 7/7 [00:00<00:00, 13.54it/s]
# num_leaves, val_score: 0.007812: 100%|#################################################| 20/20 [00:01<00:00, 11.09it/s]
# bagging, val_score: 0.003514: 100%|####################################################| 10/10 [00:00<00:00, 12.60it/s]
# feature_fraction_stage2, val_score: 0.003482: 100%|######################################| 3/3 [00:00<00:00, 12.91it/s]
# regularization_factors, val_score: 0.003482: 100%|#####################################| 20/20 [00:01<00:00, 12.31it/s]
# min_data_in_leaf, val_score: 0.003167: 100%|#############################################| 5/5 [00:00<00:00, 14.66it/s]
# feature_fraction, val_score: 0.096182: 100%|#############################################| 7/7 [00:01<00:00,  6.87it/s]
# num_leaves, val_score: 0.096182: 100%|#################################################| 20/20 [00:03<00:00,  6.65it/s]
# bagging, val_score: 0.090923: 100%|####################################################| 10/10 [00:01<00:00,  8.17it/s]
# feature_fraction_stage2, val_score: 0.087274: 100%|######################################| 6/6 [00:00<00:00,  9.78it/s]
# regularization_factors, val_score: 0.087259: 100%|#####################################| 20/20 [00:01<00:00, 10.14it/s]
# min_data_in_leaf, val_score: 0.084981: 100%|#############################################| 5/5 [00:00<00:00, 10.79it/s]
# feature_fraction, val_score: 0.048862: 100%|#############################################| 7/7 [00:01<00:00,  6.30it/s]
# num_leaves, val_score: 0.041866: 100%|#################################################| 20/20 [00:03<00:00,  6.12it/s]
# bagging, val_score: 0.036840: 100%|####################################################| 10/10 [00:01<00:00,  8.14it/s]
# feature_fraction_stage2, val_score: 0.034832: 100%|######################################| 6/6 [00:00<00:00,  9.14it/s]
# regularization_factors, val_score: 0.034832: 100%|#####################################| 20/20 [00:02<00:00,  8.94it/s]
# min_data_in_leaf, val_score: 0.034832: 100%|#############################################| 5/5 [00:00<00:00, 10.49it/s]
# feature_fraction, val_score: 0.084377: 100%|#############################################| 7/7 [00:01<00:00,  6.39it/s]
# num_leaves, val_score: 0.084377: 100%|#################################################| 20/20 [00:03<00:00,  6.55it/s]
# bagging, val_score: 0.076979: 100%|####################################################| 10/10 [00:01<00:00,  7.97it/s]
# feature_fraction_stage2, val_score: 0.075918: 100%|######################################| 6/6 [00:00<00:00,  8.77it/s]
# regularization_factors, val_score: 0.075077: 100%|#####################################| 20/20 [00:02<00:00,  9.87it/s]
# min_data_in_leaf, val_score: 0.075077: 100%|#############################################| 5/5 [00:00<00:00, 12.45it/s]
# feature_fraction, val_score: 0.074228: 100%|#############################################| 7/7 [00:01<00:00,  5.19it/s]
# num_leaves, val_score: 0.074228: 100%|#################################################| 20/20 [00:04<00:00,  4.64it/s]
# bagging, val_score: 0.066326: 100%|####################################################| 10/10 [00:01<00:00,  5.05it/s]
# feature_fraction_stage2, val_score: 0.066326: 100%|######################################| 6/6 [00:01<00:00,  5.19it/s]
# regularization_factors, val_score: 0.059945: 100%|#####################################| 20/20 [00:03<00:00,  6.08it/s]
# min_data_in_leaf, val_score: 0.059945: 100%|#############################################| 5/5 [00:00<00:00,  9.11it/s]
# feature_fraction, val_score: 0.053092: 100%|#############################################| 7/7 [00:01<00:00,  6.71it/s]
# num_leaves, val_score: 0.053092: 100%|#################################################| 20/20 [00:02<00:00,  7.27it/s]
# bagging, val_score: 0.053092: 100%|####################################################| 10/10 [00:01<00:00,  7.50it/s]
# feature_fraction_stage2, val_score: 0.053092: 100%|######################################| 6/6 [00:00<00:00,  7.42it/s]
# regularization_factors, val_score: 0.048894: 100%|#####################################| 20/20 [00:02<00:00,  9.53it/s]
# min_data_in_leaf, val_score: 0.048752: 100%|#############################################| 5/5 [00:00<00:00, 11.11it/s]
# feature_fraction, val_score: 0.067966: 100%|#############################################| 7/7 [00:01<00:00,  6.43it/s]
# num_leaves, val_score: 0.067964: 100%|#################################################| 20/20 [00:03<00:00,  5.62it/s]
# bagging, val_score: 0.066812: 100%|####################################################| 10/10 [00:01<00:00,  7.97it/s]
# feature_fraction_stage2, val_score: 0.066812: 100%|######################################| 6/6 [00:00<00:00,  8.57it/s]
# regularization_factors, val_score: 0.065328: 100%|#####################################| 20/20 [00:02<00:00,  8.28it/s]
# min_data_in_leaf, val_score: 0.059190: 100%|#############################################| 5/5 [00:00<00:00,  9.93it/s]
# feature_fraction, val_score: 0.080182: 100%|#############################################| 7/7 [00:00<00:00,  7.10it/s]
# num_leaves, val_score: 0.080182: 100%|#################################################| 20/20 [00:03<00:00,  6.52it/s]
# bagging, val_score: 0.080182: 100%|####################################################| 10/10 [00:01<00:00,  8.35it/s]
# feature_fraction_stage2, val_score: 0.078477: 100%|######################################| 6/6 [00:00<00:00,  6.76it/s]
# regularization_factors, val_score: 0.078477: 100%|#####################################| 20/20 [00:02<00:00,  8.58it/s]
# min_data_in_leaf, val_score: 0.078477: 100%|#############################################| 5/5 [00:00<00:00,  7.27it/s]
# feature_fraction, val_score: 0.036975: 100%|#############################################| 7/7 [00:01<00:00,  5.42it/s]
# num_leaves, val_score: 0.036975: 100%|#################################################| 20/20 [00:04<00:00,  4.64it/s]
# bagging, val_score: 0.035002: 100%|####################################################| 10/10 [00:01<00:00,  6.15it/s]
# feature_fraction_stage2, val_score: 0.035002: 100%|######################################| 6/6 [00:01<00:00,  4.54it/s]
# regularization_factors, val_score: 0.034399: 100%|#####################################| 20/20 [00:03<00:00,  5.80it/s]
# min_data_in_leaf, val_score: 0.034399: 100%|#############################################| 5/5 [00:00<00:00,  9.11it/s]
# feature_fraction, val_score: 0.026757: 100%|#############################################| 7/7 [00:01<00:00,  4.52it/s]
# num_leaves, val_score: 0.025105: 100%|#################################################| 20/20 [00:04<00:00,  4.45it/s]
# bagging, val_score: 0.018667: 100%|####################################################| 10/10 [00:01<00:00,  5.76it/s]
# feature_fraction_stage2, val_score: 0.015516: 100%|######################################| 6/6 [00:01<00:00,  5.78it/s]
# regularization_factors, val_score: 0.013713: 100%|#####################################| 20/20 [00:03<00:00,  6.16it/s]
# min_data_in_leaf, val_score: 0.013713: 100%|#############################################| 5/5 [00:00<00:00,  8.44it/s]
# feature_fraction, val_score: 0.000009: 100%|#############################################| 7/7 [00:00<00:00, 18.24it/s]
# num_leaves, val_score: 0.000009: 100%|#################################################| 20/20 [00:01<00:00, 17.64it/s]
# bagging, val_score: 0.000009: 100%|####################################################| 10/10 [00:00<00:00, 17.17it/s]
# feature_fraction_stage2, val_score: 0.000009: 100%|######################################| 3/3 [00:00<00:00, 16.52it/s]
# regularization_factors, val_score: 0.000009: 100%|#####################################| 20/20 [00:01<00:00, 14.08it/s]
# min_data_in_leaf, val_score: 0.000008: 100%|#############################################| 5/5 [00:00<00:00, 18.79it/s]
# feature_fraction, val_score: 0.000009: 100%|#############################################| 7/7 [00:00<00:00, 18.12it/s]
# num_leaves, val_score: 0.000009: 100%|#################################################| 20/20 [00:01<00:00, 16.19it/s]
# bagging, val_score: 0.000009: 100%|####################################################| 10/10 [00:00<00:00, 15.47it/s]
# feature_fraction_stage2, val_score: 0.000008: 100%|######################################| 6/6 [00:00<00:00, 15.37it/s]
# regularization_factors, val_score: 0.000008: 100%|#####################################| 20/20 [00:01<00:00, 14.24it/s]
# min_data_in_leaf, val_score: 0.000008: 100%|#############################################| 5/5 [00:00<00:00, 19.08it/s]
# feature_fraction, val_score: 0.000008: 100%|#############################################| 7/7 [00:00<00:00, 17.08it/s]
# num_leaves, val_score: 0.000008: 100%|#################################################| 20/20 [00:01<00:00, 13.45it/s]
# bagging, val_score: 0.000008: 100%|####################################################| 10/10 [00:00<00:00, 14.58it/s]
# feature_fraction_stage2, val_score: 0.000008: 100%|######################################| 3/3 [00:00<00:00, 13.85it/s]
# regularization_factors, val_score: 0.000007: 100%|#####################################| 20/20 [00:01<00:00, 12.25it/s]
# min_data_in_leaf, val_score: 0.000007: 100%|#############################################| 5/5 [00:00<00:00, 16.06it/s]
# feature_fraction, val_score: 0.157130: 100%|#############################################| 7/7 [00:00<00:00, 29.95it/s]
# num_leaves, val_score: 0.157130: 100%|#################################################| 20/20 [00:00<00:00, 26.60it/s]
# bagging, val_score: 0.149078: 100%|####################################################| 10/10 [00:00<00:00, 28.09it/s]
# feature_fraction_stage2, val_score: 0.149078: 100%|######################################| 6/6 [00:00<00:00, 25.32it/s]
# regularization_factors, val_score: 0.149078: 100%|#####################################| 20/20 [00:00<00:00, 21.54it/s]
# min_data_in_leaf, val_score: 0.149055: 100%|#############################################| 5/5 [00:00<00:00, 25.91it/s]
# feature_fraction, val_score: 0.000009: 100%|#############################################| 7/7 [00:00<00:00, 15.58it/s]
# num_leaves, val_score: 0.000009: 100%|#################################################| 20/20 [00:01<00:00, 16.64it/s]
# bagging, val_score: 0.000009: 100%|####################################################| 10/10 [00:00<00:00, 17.71it/s]
# feature_fraction_stage2, val_score: 0.000009: 100%|######################################| 6/6 [00:00<00:00, 18.94it/s]
# regularization_factors, val_score: 0.000009: 100%|#####################################| 20/20 [00:01<00:00, 15.35it/s]
# min_data_in_leaf, val_score: 0.000009: 100%|#############################################| 5/5 [00:00<00:00, 20.63it/s]
# feature_fraction, val_score: 0.000009: 100%|#############################################| 7/7 [00:00<00:00, 18.19it/s]
# num_leaves, val_score: 0.000009: 100%|#################################################| 20/20 [00:01<00:00, 17.52it/s]
# bagging, val_score: 0.000009: 100%|####################################################| 10/10 [00:00<00:00, 18.35it/s]
# feature_fraction_stage2, val_score: 0.000009: 100%|######################################| 6/6 [00:00<00:00, 19.06it/s]
# regularization_factors, val_score: 0.000009: 100%|#####################################| 20/20 [00:01<00:00, 15.40it/s]
# min_data_in_leaf, val_score: 0.000009: 100%|#############################################| 5/5 [00:00<00:00, 21.02it/s]
# feature_fraction, val_score: 0.089118: 100%|#############################################| 7/7 [00:00<00:00, 27.45it/s]
# num_leaves, val_score: 0.089118: 100%|#################################################| 20/20 [00:00<00:00, 22.46it/s]
# bagging, val_score: 0.044016: 100%|####################################################| 10/10 [00:00<00:00, 21.65it/s]
# feature_fraction_stage2, val_score: 0.033472: 100%|######################################| 3/3 [00:00<00:00, 20.35it/s]
# regularization_factors, val_score: 0.033472: 100%|#####################################| 20/20 [00:01<00:00, 18.35it/s]
# min_data_in_leaf, val_score: 0.021275: 100%|#############################################| 5/5 [00:00<00:00, 22.90it/s]
# feature_fraction, val_score: 0.000009: 100%|#############################################| 7/7 [00:00<00:00, 18.22it/s]
# num_leaves, val_score: 0.000009: 100%|#################################################| 20/20 [00:01<00:00, 17.81it/s]
# bagging, val_score: 0.000009: 100%|####################################################| 10/10 [00:00<00:00, 18.38it/s]
# feature_fraction_stage2, val_score: 0.000009: 100%|######################################| 6/6 [00:00<00:00, 18.84it/s]
# regularization_factors, val_score: 0.000009: 100%|#####################################| 20/20 [00:01<00:00, 15.48it/s]
# min_data_in_leaf, val_score: 0.000009: 100%|#############################################| 5/5 [00:00<00:00, 20.67it/s]
# feature_fraction, val_score: 0.000009: 100%|#############################################| 7/7 [00:00<00:00, 17.97it/s]
# num_leaves, val_score: 0.000009: 100%|#################################################| 20/20 [00:01<00:00, 14.61it/s]
# bagging, val_score: 0.000008: 100%|####################################################| 10/10 [00:00<00:00, 16.45it/s]
# feature_fraction_stage2, val_score: 0.000008: 100%|######################################| 3/3 [00:00<00:00, 13.86it/s]
# regularization_factors, val_score: 0.000008: 100%|#####################################| 20/20 [00:01<00:00, 11.83it/s]
# min_data_in_leaf, val_score: 0.000008: 100%|#############################################| 5/5 [00:00<00:00, 14.10it/s]
# feature_fraction, val_score: 0.089836: 100%|#############################################| 7/7 [00:01<00:00,  4.57it/s]
# num_leaves, val_score: 0.089836: 100%|#################################################| 20/20 [00:04<00:00,  4.89it/s]
# bagging, val_score: 0.083158: 100%|####################################################| 10/10 [00:02<00:00,  4.62it/s]
# feature_fraction_stage2, val_score: 0.079512: 100%|######################################| 3/3 [00:00<00:00,  4.26it/s]
# regularization_factors, val_score: 0.068710: 100%|#####################################| 20/20 [00:05<00:00,  3.95it/s]
# min_data_in_leaf, val_score: 0.068710: 100%|#############################################| 5/5 [00:01<00:00,  4.62it/s]
# feature_fraction, val_score: 0.173847: 100%|#############################################| 7/7 [00:01<00:00,  4.96it/s]
# num_leaves, val_score: 0.173847: 100%|#################################################| 20/20 [00:03<00:00,  5.07it/s]
# bagging, val_score: 0.173847: 100%|####################################################| 10/10 [00:01<00:00,  5.94it/s]
# feature_fraction_stage2, val_score: 0.164045: 100%|######################################| 6/6 [00:01<00:00,  5.26it/s]
# regularization_factors, val_score: 0.163397: 100%|#####################################| 20/20 [00:03<00:00,  5.18it/s]
# min_data_in_leaf, val_score: 0.154038: 100%|#############################################| 5/5 [00:00<00:00,  5.65it/s]
# feature_fraction, val_score: 0.170094: 100%|#############################################| 7/7 [00:01<00:00,  5.00it/s]
# num_leaves, val_score: 0.164901: 100%|#################################################| 20/20 [00:04<00:00,  4.88it/s]
# bagging, val_score: 0.164901: 100%|####################################################| 10/10 [00:01<00:00,  5.76it/s]
# feature_fraction_stage2, val_score: 0.162219: 100%|######################################| 6/6 [00:00<00:00,  6.01it/s]
# regularization_factors, val_score: 0.162218: 100%|#####################################| 20/20 [00:04<00:00,  4.82it/s]
# min_data_in_leaf, val_score: 0.148331: 100%|#############################################| 5/5 [00:00<00:00,  5.49it/s]
# feature_fraction, val_score: 0.110006: 100%|#############################################| 7/7 [00:01<00:00,  4.72it/s]
# num_leaves, val_score: 0.110006: 100%|#################################################| 20/20 [00:04<00:00,  4.86it/s]
# bagging, val_score: 0.101929: 100%|####################################################| 10/10 [00:01<00:00,  5.03it/s]
# feature_fraction_stage2, val_score: 0.101929: 100%|######################################| 6/6 [00:01<00:00,  4.97it/s]
# regularization_factors, val_score: 0.101929: 100%|#####################################| 20/20 [00:04<00:00,  4.66it/s]
# min_data_in_leaf, val_score: 0.101929: 100%|#############################################| 5/5 [00:01<00:00,  4.59it/s]
# feature_fraction, val_score: 0.180781: 100%|#############################################| 7/7 [00:01<00:00,  4.75it/s]
# num_leaves, val_score: 0.180781: 100%|#################################################| 20/20 [00:04<00:00,  4.97it/s]
# bagging, val_score: 0.180781: 100%|####################################################| 10/10 [00:01<00:00,  5.16it/s]
# feature_fraction_stage2, val_score: 0.170419: 100%|######################################| 3/3 [00:00<00:00,  5.21it/s]
# regularization_factors, val_score: 0.170394: 100%|#####################################| 20/20 [00:04<00:00,  4.88it/s]
# min_data_in_leaf, val_score: 0.170394: 100%|#############################################| 5/5 [00:01<00:00,  4.95it/s]
# feature_fraction, val_score: 0.085642: 100%|#############################################| 7/7 [00:01<00:00,  4.50it/s]
# num_leaves, val_score: 0.085642: 100%|#################################################| 20/20 [00:04<00:00,  4.73it/s]
# bagging, val_score: 0.085642: 100%|####################################################| 10/10 [00:02<00:00,  4.10it/s]
# feature_fraction_stage2, val_score: 0.085386: 100%|######################################| 6/6 [00:01<00:00,  4.73it/s]
# regularization_factors, val_score: 0.073729: 100%|#####################################| 20/20 [00:04<00:00,  4.43it/s]
# min_data_in_leaf, val_score: 0.056911: 100%|#############################################| 5/5 [00:01<00:00,  4.29it/s]
# feature_fraction, val_score: 0.122816: 100%|#############################################| 7/7 [00:01<00:00,  4.51it/s]
# num_leaves, val_score: 0.122816: 100%|#################################################| 20/20 [00:04<00:00,  4.70it/s]
# bagging, val_score: 0.122816: 100%|####################################################| 10/10 [00:01<00:00,  5.19it/s]
# feature_fraction_stage2, val_score: 0.122816: 100%|######################################| 3/3 [00:00<00:00,  4.88it/s]
# regularization_factors, val_score: 0.122816: 100%|#####################################| 20/20 [00:04<00:00,  4.74it/s]
# min_data_in_leaf, val_score: 0.122816: 100%|#############################################| 5/5 [00:01<00:00,  4.75it/s]
# feature_fraction, val_score: 0.085023: 100%|#############################################| 7/7 [00:01<00:00,  3.84it/s]
# num_leaves, val_score: 0.084127: 100%|#################################################| 20/20 [00:05<00:00,  3.76it/s]
# bagging, val_score: 0.084127: 100%|####################################################| 10/10 [00:02<00:00,  4.56it/s]
# feature_fraction_stage2, val_score: 0.084127: 100%|######################################| 6/6 [00:01<00:00,  3.90it/s]
# regularization_factors, val_score: 0.079750: 100%|#####################################| 20/20 [00:05<00:00,  3.92it/s]
# min_data_in_leaf, val_score: 0.079750: 100%|#############################################| 5/5 [00:01<00:00,  4.30it/s]
# feature_fraction, val_score: 0.040616: 100%|#############################################| 7/7 [00:02<00:00,  3.13it/s]
# num_leaves, val_score: 0.040605: 100%|#################################################| 20/20 [00:07<00:00,  2.60it/s]
# bagging, val_score: 0.040605: 100%|####################################################| 10/10 [00:03<00:00,  3.00it/s]
# feature_fraction_stage2, val_score: 0.040605: 100%|######################################| 6/6 [00:02<00:00,  2.84it/s]
# regularization_factors, val_score: 0.040605: 100%|#####################################| 20/20 [00:07<00:00,  2.65it/s]
# min_data_in_leaf, val_score: 0.038891: 100%|#############################################| 5/5 [00:01<00:00,  3.43it/s]
# feature_fraction, val_score: 0.068440: 100%|#############################################| 7/7 [00:00<00:00,  9.38it/s]
# num_leaves, val_score: 0.068438: 100%|#################################################| 20/20 [00:02<00:00,  8.18it/s]
# bagging, val_score: 0.064112: 100%|####################################################| 10/10 [00:01<00:00,  9.35it/s]
# feature_fraction_stage2, val_score: 0.063902: 100%|######################################| 6/6 [00:00<00:00,  9.84it/s]
# regularization_factors, val_score: 0.063617: 100%|#####################################| 20/20 [00:01<00:00, 11.32it/s]
# min_data_in_leaf, val_score: 0.057796: 100%|#############################################| 5/5 [00:00<00:00, 10.80it/s]
# feature_fraction, val_score: 0.070189: 100%|#############################################| 7/7 [00:00<00:00,  8.75it/s]
# num_leaves, val_score: 0.069127: 100%|#################################################| 20/20 [00:02<00:00,  8.05it/s]
# bagging, val_score: 0.067788: 100%|####################################################| 10/10 [00:01<00:00,  9.14it/s]
# feature_fraction_stage2, val_score: 0.065395: 100%|######################################| 6/6 [00:00<00:00,  8.98it/s]
# regularization_factors, val_score: 0.064590: 100%|#####################################| 20/20 [00:01<00:00, 10.32it/s]
# min_data_in_leaf, val_score: 0.064590: 100%|#############################################| 5/5 [00:00<00:00, 11.04it/s]
# feature_fraction, val_score: 0.003852: 100%|#############################################| 7/7 [00:01<00:00,  6.24it/s]
# num_leaves, val_score: 0.003852: 100%|#################################################| 20/20 [00:03<00:00,  5.87it/s]
# bagging, val_score: 0.003852: 100%|####################################################| 10/10 [00:01<00:00,  7.38it/s]
# feature_fraction_stage2, val_score: 0.003852: 100%|######################################| 6/6 [00:00<00:00,  7.01it/s]
# regularization_factors, val_score: 0.003664: 100%|#####################################| 20/20 [00:02<00:00,  7.65it/s]
# min_data_in_leaf, val_score: 0.003664: 100%|#############################################| 5/5 [00:00<00:00,  8.91it/s]
# feature_fraction, val_score: 0.004460: 100%|#############################################| 7/7 [00:01<00:00,  6.07it/s]
# num_leaves, val_score: 0.004460: 100%|#################################################| 20/20 [00:03<00:00,  5.41it/s]
# bagging, val_score: 0.003449: 100%|####################################################| 10/10 [00:01<00:00,  6.07it/s]
# feature_fraction_stage2, val_score: 0.003263: 100%|######################################| 3/3 [00:00<00:00,  6.40it/s]
# regularization_factors, val_score: 0.003203: 100%|#####################################| 20/20 [00:02<00:00,  6.97it/s]
# min_data_in_leaf, val_score: 0.000620: 100%|#############################################| 5/5 [00:00<00:00,  6.59it/s]
# feature_fraction, val_score: 0.023879: 100%|#############################################| 7/7 [00:00<00:00,  8.32it/s]
# num_leaves, val_score: 0.023879: 100%|#################################################| 20/20 [00:02<00:00,  7.09it/s]
# bagging, val_score: 0.022113: 100%|####################################################| 10/10 [00:01<00:00,  6.77it/s]
# feature_fraction_stage2, val_score: 0.019098: 100%|######################################| 3/3 [00:00<00:00,  6.14it/s]
# regularization_factors, val_score: 0.017319: 100%|#####################################| 20/20 [00:02<00:00,  7.21it/s]
# min_data_in_leaf, val_score: 0.017319: 100%|#############################################| 5/5 [00:00<00:00,  8.70it/s]
# feature_fraction, val_score: 0.001524: 100%|#############################################| 7/7 [00:01<00:00,  6.35it/s]
# num_leaves, val_score: 0.001524: 100%|#################################################| 20/20 [00:03<00:00,  6.41it/s]
# bagging, val_score: 0.001221: 100%|####################################################| 10/10 [00:01<00:00,  6.53it/s]
# feature_fraction_stage2, val_score: 0.001221: 100%|######################################| 6/6 [00:01<00:00,  5.48it/s]
# regularization_factors, val_score: 0.001214: 100%|#####################################| 20/20 [00:03<00:00,  6.37it/s]
# min_data_in_leaf, val_score: 0.000099: 100%|#############################################| 5/5 [00:00<00:00,  6.65it/s]
# feature_fraction, val_score: 0.028667: 100%|#############################################| 7/7 [00:00<00:00,  8.22it/s]
# num_leaves, val_score: 0.028292: 100%|#################################################| 20/20 [00:02<00:00,  7.46it/s]
# bagging, val_score: 0.023864: 100%|####################################################| 10/10 [00:01<00:00,  7.52it/s]
# feature_fraction_stage2, val_score: 0.022537: 100%|######################################| 3/3 [00:00<00:00,  7.65it/s]
# regularization_factors, val_score: 0.021781: 100%|#####################################| 20/20 [00:02<00:00,  7.88it/s]
# min_data_in_leaf, val_score: 0.021781: 100%|#############################################| 5/5 [00:00<00:00,  9.98it/s]
# feature_fraction, val_score: 0.020074: 100%|#############################################| 7/7 [00:01<00:00,  6.90it/s]
# num_leaves, val_score: 0.020074: 100%|#################################################| 20/20 [00:03<00:00,  6.53it/s]
# bagging, val_score: 0.020074: 100%|####################################################| 10/10 [00:01<00:00,  6.78it/s]
# feature_fraction_stage2, val_score: 0.018307: 100%|######################################| 3/3 [00:00<00:00,  6.96it/s]
# regularization_factors, val_score: 0.017185: 100%|#####################################| 20/20 [00:02<00:00,  8.68it/s]
# min_data_in_leaf, val_score: 0.017185: 100%|#############################################| 5/5 [00:00<00:00,  8.79it/s]
# feature_fraction, val_score: 0.036901: 100%|#############################################| 7/7 [00:00<00:00,  7.30it/s]
# num_leaves, val_score: 0.036636: 100%|#################################################| 20/20 [00:02<00:00,  6.78it/s]
# bagging, val_score: 0.036636: 100%|####################################################| 10/10 [00:01<00:00,  7.59it/s]
# feature_fraction_stage2, val_score: 0.036411: 100%|######################################| 3/3 [00:00<00:00,  7.82it/s]
# regularization_factors, val_score: 0.036410: 100%|#####################################| 20/20 [00:02<00:00,  8.48it/s]
# min_data_in_leaf, val_score: 0.036389: 100%|#############################################| 5/5 [00:00<00:00,  9.79it/s]
# feature_fraction, val_score: 0.094523: 100%|#############################################| 7/7 [00:00<00:00, 10.26it/s]
# num_leaves, val_score: 0.094523: 100%|#################################################| 20/20 [00:02<00:00,  8.95it/s]
# bagging, val_score: 0.066228: 100%|####################################################| 10/10 [00:00<00:00, 10.00it/s]
# feature_fraction_stage2, val_score: 0.066228: 100%|######################################| 3/3 [00:00<00:00, 11.79it/s]
# regularization_factors, val_score: 0.066215: 100%|#####################################| 20/20 [00:01<00:00, 11.22it/s]
# min_data_in_leaf, val_score: 0.037452: 100%|#############################################| 5/5 [00:00<00:00, 11.42it/s]
# feature_fraction, val_score: 0.068159: 100%|#############################################| 7/7 [00:00<00:00,  9.22it/s]
# num_leaves, val_score: 0.068159: 100%|#################################################| 20/20 [00:02<00:00,  9.44it/s]
# bagging, val_score: 0.044586: 100%|####################################################| 10/10 [00:01<00:00,  9.49it/s]
# feature_fraction_stage2, val_score: 0.044586: 100%|######################################| 6/6 [00:00<00:00,  9.45it/s]
# regularization_factors, val_score: 0.044224: 100%|#####################################| 20/20 [00:01<00:00, 10.39it/s]
# min_data_in_leaf, val_score: 0.044224: 100%|#############################################| 5/5 [00:00<00:00, 10.90it/s]
# feature_fraction, val_score: 0.061128: 100%|#############################################| 7/7 [00:00<00:00, 10.28it/s]
# num_leaves, val_score: 0.061128: 100%|#################################################| 20/20 [00:02<00:00,  9.90it/s]
# bagging, val_score: 0.054692: 100%|####################################################| 10/10 [00:00<00:00, 11.18it/s]
# feature_fraction_stage2, val_score: 0.054692: 100%|######################################| 6/6 [00:00<00:00, 11.59it/s]
# regularization_factors, val_score: 0.054691: 100%|#####################################| 20/20 [00:01<00:00, 12.18it/s]
# min_data_in_leaf, val_score: 0.054691: 100%|#############################################| 5/5 [00:00<00:00, 13.46it/s]
# feature_fraction, val_score: 0.087987: 100%|#############################################| 7/7 [00:00<00:00,  9.66it/s]
# num_leaves, val_score: 0.087987: 100%|#################################################| 20/20 [00:02<00:00,  9.43it/s]
# bagging, val_score: 0.087987: 100%|####################################################| 10/10 [00:00<00:00, 10.60it/s]
# ...
# min_data_in_leaf, val_score: 0.159863: 100%|#############################################| 5/5 [00:00<00:00,  5.22it/s]
# feature_fraction, val_score: 0.123411: 100%|#############################################| 7/7 [00:01<00:00,  4.85it/s]
# num_leaves, val_score: 0.123411: 100%|#################################################| 20/20 [00:04<00:00,  4.81it/s]
# bagging, val_score: 0.123085: 100%|####################################################| 10/10 [00:02<00:00,  4.93it/s]
# feature_fraction_stage2, val_score: 0.123085: 100%|######################################| 6/6 [00:01<00:00,  4.62it/s]
# regularization_factors, val_score: 0.123083: 100%|#####################################| 20/20 [00:04<00:00,  4.59it/s]
# min_data_in_leaf, val_score: 0.109542: 100%|#############################################| 5/5 [00:01<00:00,  4.82it/s]
# feature_fraction, val_score: 0.162835: 100%|#############################################| 7/7 [00:01<00:00,  4.95it/s]
# num_leaves, val_score: 0.162835: 100%|#################################################| 20/20 [00:04<00:00,  4.43it/s]
# bagging, val_score: 0.161940: 100%|####################################################| 10/10 [00:02<00:00,  4.56it/s]
# feature_fraction_stage2, val_score: 0.152677: 100%|######################################| 3/3 [00:00<00:00,  4.62it/s]
# regularization_factors, val_score: 0.152676: 100%|#####################################| 20/20 [00:04<00:00,  4.07it/s]
# min_data_in_leaf, val_score: 0.151475: 100%|#############################################| 5/5 [00:01<00:00,  4.61it/s]
# feature_fraction, val_score: 0.160063: 100%|#############################################| 7/7 [00:01<00:00,  4.73it/s]
# num_leaves, val_score: 0.160063: 100%|#################################################| 20/20 [00:04<00:00,  4.67it/s]
# bagging, val_score: 0.146072: 100%|####################################################| 10/10 [00:01<00:00,  5.23it/s]
# feature_fraction_stage2, val_score: 0.146072: 100%|######################################| 6/6 [00:01<00:00,  5.37it/s]
# regularization_factors, val_score: 0.146071: 100%|#####################################| 20/20 [00:04<00:00,  4.71it/s]
# min_data_in_leaf, val_score: 0.146071: 100%|#############################################| 5/5 [00:00<00:00,  5.59it/s]
# feature_fraction, val_score: 0.155872: 100%|#############################################| 7/7 [00:01<00:00,  5.19it/s]
# num_leaves, val_score: 0.155872: 100%|#################################################| 20/20 [00:04<00:00,  4.36it/s]
# bagging, val_score: 0.151703: 100%|####################################################| 10/10 [00:02<00:00,  4.80it/s]
# feature_fraction_stage2, val_score: 0.151703: 100%|######################################| 6/6 [00:01<00:00,  4.98it/s]
# regularization_factors, val_score: 0.151702: 100%|#####################################| 20/20 [00:04<00:00,  4.66it/s]
# min_data_in_leaf, val_score: 0.151702: 100%|#############################################| 5/5 [00:01<00:00,  4.87it/s]
# feature_fraction, val_score: 0.087932: 100%|#############################################| 7/7 [00:00<00:00,  8.02it/s]
# num_leaves, val_score: 0.087932: 100%|#################################################| 20/20 [00:02<00:00,  6.97it/s]
# bagging, val_score: 0.086151: 100%|####################################################| 10/10 [00:01<00:00,  7.99it/s]
# feature_fraction_stage2, val_score: 0.086107: 100%|######################################| 6/6 [00:00<00:00,  7.37it/s]
# regularization_factors, val_score: 0.086107: 100%|#####################################| 20/20 [00:02<00:00,  7.40it/s]
# min_data_in_leaf, val_score: 0.067659: 100%|#############################################| 5/5 [00:00<00:00,  7.46it/s]
# feature_fraction, val_score: 0.089212: 100%|#############################################| 7/7 [00:00<00:00,  7.81it/s]
# num_leaves, val_score: 0.089212: 100%|#################################################| 20/20 [00:02<00:00,  8.51it/s]
# bagging, val_score: 0.089212: 100%|####################################################| 10/10 [00:01<00:00,  8.55it/s]
# feature_fraction_stage2, val_score: 0.088606: 100%|######################################| 6/6 [00:00<00:00,  8.05it/s]
# regularization_factors, val_score: 0.079578: 100%|#####################################| 20/20 [00:02<00:00,  8.71it/s]
# min_data_in_leaf, val_score: 0.069358: 100%|#############################################| 5/5 [00:00<00:00,  8.82it/s]
# feature_fraction, val_score: 0.080145: 100%|#############################################| 7/7 [00:00<00:00,  8.02it/s]
# num_leaves, val_score: 0.080145: 100%|#################################################| 20/20 [00:02<00:00,  8.41it/s]
# bagging, val_score: 0.080145: 100%|####################################################| 10/10 [00:01<00:00,  8.78it/s]
# feature_fraction_stage2, val_score: 0.080145: 100%|######################################| 6/6 [00:00<00:00,  8.84it/s]
# regularization_factors, val_score: 0.080145: 100%|#####################################| 20/20 [00:02<00:00,  8.80it/s]
# min_data_in_leaf, val_score: 0.080145: 100%|#############################################| 5/5 [00:00<00:00,  8.98it/s]
# feature_fraction, val_score: 0.094326: 100%|#############################################| 7/7 [00:00<00:00, 10.15it/s]
# num_leaves, val_score: 0.094326: 100%|#################################################| 20/20 [00:03<00:00,  6.15it/s]
# bagging, val_score: 0.090417: 100%|####################################################| 10/10 [00:01<00:00,  7.54it/s]
# feature_fraction_stage2, val_score: 0.090417: 100%|######################################| 3/3 [00:00<00:00,  8.81it/s]
# regularization_factors, val_score: 0.087555: 100%|#####################################| 20/20 [00:02<00:00,  7.80it/s]
# min_data_in_leaf, val_score: 0.087555: 100%|#############################################| 5/5 [00:00<00:00,  8.71it/s]
# feature_fraction, val_score: 0.091428: 100%|#############################################| 7/7 [00:00<00:00,  8.30it/s]
# num_leaves, val_score: 0.091428: 100%|#################################################| 20/20 [00:02<00:00,  6.99it/s]
# bagging, val_score: 0.090808: 100%|####################################################| 10/10 [00:01<00:00,  8.10it/s]
# feature_fraction_stage2, val_score: 0.090216: 100%|######################################| 6/6 [00:00<00:00,  9.36it/s]
# regularization_factors, val_score: 0.088011: 100%|#####################################| 20/20 [00:02<00:00,  8.68it/s]
# min_data_in_leaf, val_score: 0.074821: 100%|#############################################| 5/5 [00:00<00:00,  9.52it/s]
# feature_fraction, val_score: 0.090798: 100%|#############################################| 7/7 [00:00<00:00,  8.30it/s]
# num_leaves, val_score: 0.090798: 100%|#################################################| 20/20 [00:02<00:00,  6.72it/s]
# bagging, val_score: 0.080870: 100%|####################################################| 10/10 [00:01<00:00,  7.22it/s]
# feature_fraction_stage2, val_score: 0.080868: 100%|######################################| 6/6 [00:00<00:00,  6.68it/s]
# regularization_factors, val_score: 0.080595: 100%|#####################################| 20/20 [00:02<00:00,  6.84it/s]
# min_data_in_leaf, val_score: 0.071341: 100%|#############################################| 5/5 [00:00<00:00,  8.61it/s]
# feature_fraction, val_score: 0.097534: 100%|#############################################| 7/7 [00:00<00:00,  9.38it/s]
# num_leaves, val_score: 0.097534: 100%|#################################################| 20/20 [00:02<00:00,  7.54it/s]
# bagging, val_score: 0.086393: 100%|####################################################| 10/10 [00:01<00:00,  9.38it/s]
# feature_fraction_stage2, val_score: 0.082662: 100%|######################################| 6/6 [00:00<00:00,  8.41it/s]
# regularization_factors, val_score: 0.077683: 100%|#####################################| 20/20 [00:02<00:00,  8.66it/s]
# min_data_in_leaf, val_score: 0.077683: 100%|#############################################| 5/5 [00:00<00:00, 13.01it/s]
# feature_fraction, val_score: 0.091969: 100%|#############################################| 7/7 [00:00<00:00,  7.60it/s]
# num_leaves, val_score: 0.091969: 100%|#################################################| 20/20 [00:02<00:00,  7.04it/s]
# bagging, val_score: 0.088014: 100%|####################################################| 10/10 [00:01<00:00,  7.32it/s]
# feature_fraction_stage2, val_score: 0.088014: 100%|######################################| 6/6 [00:00<00:00,  7.45it/s]
# regularization_factors, val_score: 0.087819: 100%|#####################################| 20/20 [00:02<00:00,  7.22it/s]
# min_data_in_leaf, val_score: 0.077694: 100%|#############################################| 5/5 [00:00<00:00,  9.99it/s]
# feature_fraction, val_score: 0.093436: 100%|#############################################| 7/7 [00:00<00:00, 10.36it/s]
# num_leaves, val_score: 0.093436: 100%|#################################################| 20/20 [00:01<00:00, 10.44it/s]
# bagging, val_score: 0.092342: 100%|####################################################| 10/10 [00:00<00:00, 11.06it/s]
# feature_fraction_stage2, val_score: 0.092342: 100%|######################################| 6/6 [00:00<00:00, 10.94it/s]
# regularization_factors, val_score: 0.092341: 100%|#####################################| 20/20 [00:01<00:00, 10.41it/s]
# min_data_in_leaf, val_score: 0.088141: 100%|#############################################| 5/5 [00:00<00:00, 11.99it/s]
# feature_fraction, val_score: 0.052440: 100%|#############################################| 7/7 [00:00<00:00, 10.98it/s]
# num_leaves, val_score: 0.052440: 100%|#################################################| 20/20 [00:01<00:00, 11.30it/s]
# bagging, val_score: 0.052440: 100%|####################################################| 10/10 [00:00<00:00, 13.29it/s]
# feature_fraction_stage2, val_score: 0.052432: 100%|######################################| 3/3 [00:00<00:00, 11.49it/s]
# regularization_factors, val_score: 0.052265: 100%|#####################################| 20/20 [00:01<00:00, 11.48it/s]
# min_data_in_leaf, val_score: 0.000147: 100%|#############################################| 5/5 [00:00<00:00, 15.56it/s]
# feature_fraction, val_score: 0.055948: 100%|#############################################| 7/7 [00:00<00:00, 11.55it/s]
# num_leaves, val_score: 0.055948: 100%|#################################################| 20/20 [00:02<00:00,  9.53it/s]
# bagging, val_score: 0.053967: 100%|####################################################| 10/10 [00:00<00:00, 10.02it/s]
# feature_fraction_stage2, val_score: 0.053967: 100%|######################################| 3/3 [00:00<00:00,  9.84it/s]
# regularization_factors, val_score: 0.053914: 100%|#####################################| 20/20 [00:01<00:00, 10.27it/s]
# min_data_in_leaf, val_score: 0.000018: 100%|#############################################| 5/5 [00:00<00:00, 10.88it/s]
# feature_fraction, val_score: 0.055874: 100%|#############################################| 7/7 [00:00<00:00,  9.33it/s]
# num_leaves, val_score: 0.055874: 100%|#################################################| 20/20 [00:01<00:00, 10.72it/s]
# bagging, val_score: 0.053534: 100%|####################################################| 10/10 [00:00<00:00, 15.97it/s]
# feature_fraction_stage2, val_score: 0.053037: 100%|######################################| 3/3 [00:00<00:00, 14.42it/s]
# regularization_factors, val_score: 0.053037: 100%|#####################################| 20/20 [00:01<00:00, 15.60it/s]
# min_data_in_leaf, val_score: 0.000008: 100%|#############################################| 5/5 [00:00<00:00, 11.94it/s]
# feature_fraction, val_score: 0.052364: 100%|#############################################| 7/7 [00:00<00:00, 10.01it/s]
# num_leaves, val_score: 0.052364: 100%|#################################################| 20/20 [00:01<00:00, 11.15it/s]
# bagging, val_score: 0.052238: 100%|####################################################| 10/10 [00:00<00:00, 13.31it/s]
# feature_fraction_stage2, val_score: 0.052238: 100%|######################################| 3/3 [00:00<00:00, 10.82it/s]
# regularization_factors, val_score: 0.052238: 100%|#####################################| 20/20 [00:01<00:00, 10.16it/s]
# min_data_in_leaf, val_score: 0.000009: 100%|#############################################| 5/5 [00:00<00:00, 12.80it/s]
# feature_fraction, val_score: 0.052481: 100%|#############################################| 7/7 [00:00<00:00,  9.69it/s]
# num_leaves, val_score: 0.052481: 100%|#################################################| 20/20 [00:02<00:00,  9.20it/s]
# bagging, val_score: 0.052085: 100%|####################################################| 10/10 [00:00<00:00, 12.69it/s]
# feature_fraction_stage2, val_score: 0.052049: 100%|######################################| 6/6 [00:00<00:00, 10.52it/s]
# regularization_factors, val_score: 0.052036: 100%|#####################################| 20/20 [00:01<00:00, 11.57it/s]
# min_data_in_leaf, val_score: 0.028829: 100%|#############################################| 5/5 [00:00<00:00, 18.75it/s]
# feature_fraction, val_score: 0.052883: 100%|#############################################| 7/7 [00:00<00:00,  9.00it/s]
# num_leaves, val_score: 0.052883: 100%|#################################################| 20/20 [00:01<00:00, 10.95it/s]
# bagging, val_score: 0.052883: 100%|####################################################| 10/10 [00:00<00:00, 13.18it/s]
# feature_fraction_stage2, val_score: 0.052859: 100%|######################################| 3/3 [00:00<00:00, 10.88it/s]
# regularization_factors, val_score: 0.052846: 100%|#####################################| 20/20 [00:01<00:00, 11.28it/s]
# min_data_in_leaf, val_score: 0.000032: 100%|#############################################| 5/5 [00:00<00:00, 13.56it/s]
# feature_fraction, val_score: 0.056590: 100%|#############################################| 7/7 [00:00<00:00, 11.72it/s]
# num_leaves, val_score: 0.056590: 100%|#################################################| 20/20 [00:02<00:00,  9.69it/s]
# bagging, val_score: 0.054767: 100%|####################################################| 10/10 [00:01<00:00,  9.04it/s]
# feature_fraction_stage2, val_score: 0.054767: 100%|######################################| 3/3 [00:00<00:00,  7.95it/s]
# regularization_factors, val_score: 0.054766: 100%|#####################################| 20/20 [00:02<00:00,  9.11it/s]
# min_data_in_leaf, val_score: 0.000037: 100%|#############################################| 5/5 [00:00<00:00,  9.46it/s]
# feature_fraction, val_score: 0.055734: 100%|#############################################| 7/7 [00:00<00:00, 10.71it/s]
# num_leaves, val_score: 0.055734: 100%|#################################################| 20/20 [00:02<00:00,  7.14it/s]
# bagging, val_score: 0.055137: 100%|####################################################| 10/10 [00:01<00:00,  9.09it/s]
# feature_fraction_stage2, val_score: 0.055137: 100%|######################################| 3/3 [00:00<00:00,  7.63it/s]
# regularization_factors, val_score: 0.055137: 100%|#####################################| 20/20 [00:02<00:00,  8.58it/s]
# min_data_in_leaf, val_score: 0.010535: 100%|#############################################| 5/5 [00:00<00:00,  8.76it/s]
# feature_fraction, val_score: 0.052203: 100%|#############################################| 7/7 [00:00<00:00,  9.01it/s]
# num_leaves, val_score: 0.052203: 100%|#################################################| 20/20 [00:02<00:00,  8.87it/s]
# bagging, val_score: 0.052151: 100%|####################################################| 10/10 [00:00<00:00, 13.24it/s]
# feature_fraction_stage2, val_score: 0.052151: 100%|######################################| 6/6 [00:00<00:00,  8.90it/s]
# regularization_factors, val_score: 0.052112: 100%|#####################################| 20/20 [00:01<00:00, 10.40it/s]
# min_data_in_leaf, val_score: 0.000006: 100%|#############################################| 5/5 [00:00<00:00, 13.91it/s]

# %%
list_0
# Out:
# []
