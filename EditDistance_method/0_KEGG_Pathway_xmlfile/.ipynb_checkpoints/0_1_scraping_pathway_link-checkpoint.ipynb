# %% [markdown]
# # 0_1_scraping_pathway_link
# Get the link of the Pathway ID associated with each Target by scraping.
#
# ### input
# - 7_Target_Drug_SE_TI_from_SIDER_DrugBank/tbl_drug_target_TI_SE.pkl : A file with Target and Drug and SE/TI and KEGG ID
#
# ### output
# - 0_KEGG_Pathway_xmlfile/output/KEGG_ID_Pathway_link.csv : A file linking KEGG ID and Pathway link
# - 0_KEGG_Pathway_xmlfile/output/tbl_drug_target_TI_SE_Pathway.csv : A file with Target and Drug and SE/TI and KEGG ID and Pathway ID

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.stats as st
import re
import time

# %%
import pickle
with open('../7_Target_Drug_SE_TI_from_SIDER_DrugBank/tbl_drug_target_TI_SE.pkl', 'rb') as web:
    df = pickle.load(web)

# %%
df['id'] = df['entry_id'].str.replace('hsa:', '').apply(int)

# %%
df
# Out:
#               Drug                                        target_name  \
# 0             4-AP  Potassium voltage-gated channel subfamily A me...
# 1             4-AP  Potassium voltage-gated channel subfamily C me...
# 2             4-AP  Potassium voltage-gated channel subfamily D me...
# 3     disopyramide  Potassium voltage-gated channel subfamily D me...
# 4       imipramine  Potassium voltage-gated channel subfamily D me...
# ...            ...                                                ...
# 2743          zinc                                  Tumor protein p73
# 2744    zonisamide                              Carbonic anhydrase 13
# 2745    zonisamide               Carbonic anhydrase 5B, mitochondrial
# 2746    zonisamide                 Carbonic anhydrase-related protein
# 2747    zonisamide                      Sodium channel subunit beta-4
#
#      target_type                                                 TI  \
# 0        Protein       ['Multiple sclerosis', 'Walking disability']
# 1        Protein       ['Multiple sclerosis', 'Walking disability']
# 2        Protein       ['Multiple sclerosis', 'Walking disability']
# 3        Protein  ['Arrhythmia', 'Bundle branch block', 'Sudden ...
# 4        Protein  ['Alcoholism', 'Depression', 'Endogenous depre...
# ...          ...                                                ...
# 2743     Protein  ['Hepato-lenticular degeneration', 'Liver diso...
# 2744     Protein  ['Epilepsy', 'Partial seizures', 'Sudden unexp...
# 2745     Protein  ['Epilepsy', 'Partial seizures', 'Sudden unexp...
# 2746     Protein  ['Epilepsy', 'Partial seizures', 'Sudden unexp...
# 2747     Protein  ['Epilepsy', 'Partial seizures', 'Sudden unexp...
#
#                                                      SE gene_name  \
# 0     ['Anaphylactic shock', 'Angioedema', 'Anxiety'...     KCNA4
# 1     ['Anaphylactic shock', 'Angioedema', 'Anxiety'...     KCNC3
# 2     ['Anaphylactic shock', 'Angioedema', 'Anxiety'...     KCND2
# 3     ['Agranulocytosis', 'Angioedema', 'Anorexia', ...     KCND2
# 4     ['Abdominal cramps', 'Abdominal pain', 'Adenit...     KCND2
# ...                                                 ...       ...
# 2743             ['Pancreatitis', 'Gastric irritation']      TP73
# 2744  ['Abdominal pain', 'Congenital anomaly', 'Rena...      CA13
# 2745  ['Abdominal pain', 'Congenital anomaly', 'Rena...      CA5B
# 2746  ['Abdominal pain', 'Congenital anomaly', 'Rena...       CA8
# 2747  ['Abdominal pain', 'Congenital anomaly', 'Rena...     SCN4B
#
#      gene_symbols    entry_id   name      id
# 0           kcna4    hsa:3739  KCNA4    3739
# 1           kcnc3    hsa:3748  KCNC3    3748
# 2           kcnd2    hsa:3751  KCND2    3751
# 3           kcnd2    hsa:3751  KCND2    3751
# 4           kcnd2    hsa:3751  KCND2    3751
# ...           ...         ...    ...     ...
# 2743         tp73    hsa:7161   TP73    7161
# 2744         ca13  hsa:377677   CA13  377677
# 2745         ca5b   hsa:11238   CA5B   11238
# 2746          ca8     hsa:767    CA8     767
# 2747        scn4b    hsa:6330  SCN4B    6330
#
# [2748 rows x 10 columns]

# %%
df_id = df[['id']].drop_duplicates().reset_index(drop = True)

# %%
df_id
# Out:
#          id
# 0      3739
# 1      3748
# 2      3751
# 3      3752
# 4       240
# ..      ...
# 741    7161
# 742  377677
# 743   11238
# 744     767
# 745    6330
#
# [746 rows x 1 columns]

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [C:\Users\nakamura\.wdm\drivers\chromedriver\win32\97.0.4692.71\chromedriver.exe] found in cache
# <ipython-input-7-4c36b37c1d04>:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
import time
from selenium.common.exceptions import TimeoutException

# %%
import requests
from bs4 import BeautifulSoup

# %%
df_link = pd.DataFrame()
for g in df_id['id']:
    driver.get('https://www.genome.jp/dbget-bin/www_bget?hsa:'+str(g))
    time.sleep(1)
    source = driver.page_source
    soup = BeautifulSoup(source,'html.parser')
    p = []
    hsa_link = []
    for k in soup('a'):
        p.append(k.get('href'))
    for i in [x for x in p if x is not None]:
        if '/pathway/' in i:
            hsa_link.append('https://www.genome.jp'+i)
            #print(i)
        else:
            pass
    for s in hsa_link:
        df_link = pd.concat([df_link, pd.DataFrame([[g,s.split('+')[0]]],columns = ['HSA','hsa_link'])])
df_link = df_link.reset_index(drop = True)

# %%
df_link
# Out:
#         HSA                                hsa_link
# 0      3739  https://www.genome.jp/pathway/hsa04927
# 1      3739  https://www.genome.jp/pathway/hsa04934
# 2      3748  https://www.genome.jp/pathway/hsa05017
# 3      3751  https://www.genome.jp/pathway/hsa04726
# 4      3752  https://www.genome.jp/pathway/hsa05017
# ...     ...                                     ...
# 5899  11238  https://www.genome.jp/pathway/hsa00910
# 5900  11238  https://www.genome.jp/pathway/hsa01100
# 5901    767  https://www.genome.jp/pathway/hsa00910
# 5902    767  https://www.genome.jp/pathway/hsa01100
# 5903   6330  https://www.genome.jp/pathway/hsa04261
#
# [5904 rows x 2 columns]

# %%
df_link.to_csv('output/KEGG_ID_Pathway_link.csv',encoding = 'utf-8')

# %%
driver.close()

# %%
df_link['hsa_map'] = df_link['hsa_link'].str.replace('https://www.genome.jp/pathway/', '')
# Out:
# <ipython-input-14-72451ddc5f66>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_link['hsa_map'] = df_link['hsa_link'].str.replace('https://www.genome.jp/pathway/', '')

# %%
df_link = df_link.drop(columns=['hsa_link']).drop_duplicates()

# %%
df_all = pd.merge(df, df_link.groupby(['HSA'])['hsa_map'].apply(list).reset_index(), left_on = 'id', right_on = 'HSA').drop(columns=['id'])

# %%
df_all
# Out:
#               Drug                                        target_name  \
# 0             4-AP  Potassium voltage-gated channel subfamily A me...
# 1             4-AP  Potassium voltage-gated channel subfamily C me...
# 2             4-AP  Potassium voltage-gated channel subfamily D me...
# 3     disopyramide  Potassium voltage-gated channel subfamily D me...
# 4       imipramine  Potassium voltage-gated channel subfamily D me...
# ...            ...                                                ...
# 2743          zinc                                  Tumor protein p73
# 2744    zonisamide                              Carbonic anhydrase 13
# 2745    zonisamide               Carbonic anhydrase 5B, mitochondrial
# 2746    zonisamide                 Carbonic anhydrase-related protein
# 2747    zonisamide                      Sodium channel subunit beta-4
#
#      target_type                                                 TI  \
# 0        Protein       ['Multiple sclerosis', 'Walking disability']
# 1        Protein       ['Multiple sclerosis', 'Walking disability']
# 2        Protein       ['Multiple sclerosis', 'Walking disability']
# 3        Protein  ['Arrhythmia', 'Bundle branch block', 'Sudden ...
# 4        Protein  ['Alcoholism', 'Depression', 'Endogenous depre...
# ...          ...                                                ...
# 2743     Protein  ['Hepato-lenticular degeneration', 'Liver diso...
# 2744     Protein  ['Epilepsy', 'Partial seizures', 'Sudden unexp...
# 2745     Protein  ['Epilepsy', 'Partial seizures', 'Sudden unexp...
# 2746     Protein  ['Epilepsy', 'Partial seizures', 'Sudden unexp...
# 2747     Protein  ['Epilepsy', 'Partial seizures', 'Sudden unexp...
#
#                                                      SE gene_name  \
# 0     ['Anaphylactic shock', 'Angioedema', 'Anxiety'...     KCNA4
# 1     ['Anaphylactic shock', 'Angioedema', 'Anxiety'...     KCNC3
# 2     ['Anaphylactic shock', 'Angioedema', 'Anxiety'...     KCND2
# 3     ['Agranulocytosis', 'Angioedema', 'Anorexia', ...     KCND2
# 4     ['Abdominal cramps', 'Abdominal pain', 'Adenit...     KCND2
# ...                                                 ...       ...
# 2743             ['Pancreatitis', 'Gastric irritation']      TP73
# 2744  ['Abdominal pain', 'Congenital anomaly', 'Rena...      CA13
# 2745  ['Abdominal pain', 'Congenital anomaly', 'Rena...      CA5B
# 2746  ['Abdominal pain', 'Congenital anomaly', 'Rena...       CA8
# 2747  ['Abdominal pain', 'Congenital anomaly', 'Rena...     SCN4B
#
#      gene_symbols    entry_id   name     HSA  \
# 0           kcna4    hsa:3739  KCNA4    3739
# 1           kcnc3    hsa:3748  KCNC3    3748
# 2           kcnd2    hsa:3751  KCND2    3751
# 3           kcnd2    hsa:3751  KCND2    3751
# 4           kcnd2    hsa:3751  KCND2    3751
# ...           ...         ...    ...     ...
# 2743         tp73    hsa:7161   TP73    7161
# 2744         ca13  hsa:377677   CA13  377677
# 2745         ca5b   hsa:11238   CA5B   11238
# 2746          ca8     hsa:767    CA8     767
# 2747        scn4b    hsa:6330  SCN4B    6330
#
#                                        hsa_map
# 0                         [hsa04927, hsa04934]
# 1                                   [hsa05017]
# 2                                   [hsa04726]
# 3                                   [hsa04726]
# 4                                   [hsa04726]
# ...                                        ...
# 2743  [hsa04115, hsa04390, hsa04722, hsa05162]
# 2744                      [hsa00910, hsa01100]
# 2745                      [hsa00910, hsa01100]
# 2746                      [hsa00910, hsa01100]
# 2747                                [hsa04261]
#
# [2748 rows x 11 columns]

# %%
df_all.to_csv('output/tbl_drug_target_TI_SE_Pathway.csv',encoding = 'utf-8')
